# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
# !pip install yfinance
# Out:
# ...
#   Using cached yfinance-0.1.64.tar.gz (26 kB)
# ...
#   Using cached multitasking-0.0.9.tar.gz (8.1 kB)
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.64-py2.py3-none-any.whl size=24095 sha256=008dc82200cb1a704b16e34b6a2cee52fc36e622173d3a5cbeee6f7d47a543f1
#   Stored in directory: c:\users\damien lim\appdata\local\pip\cache\wheels\f9\e9\7e\8b13db3bf3aeb5049d759e10702736fb96753089ac950fddc0
# ...
#   Created wheel for multitasking: filename=multitasking-0.0.9-py3-none-any.whl size=8368 sha256=15ec5c6a55cc82d01ceeb937d20acc4ba36602e911a2920272a5bd0518ce5f8a
#   Stored in directory: c:\users\damien lim\appdata\local\pip\cache\wheels\57\6d\a3\a39b839cc75274d2acfb1c58bfead2f726c6577fe8c4723f13
# Successfully built yfinance multitasking
# ...

# %%
import yfinance as yf
import yahoo_fin.stock_info as si

# %%
c09=yf.Ticker('C09.SI')
c09.info
# Out:
# {'zip': '048619',
#  'sector': 'Real Estate',
# ...

# %%
hist=c09.history(period="max")
hist.plot(kind="line",figsize=(12,12),subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>], dtype=object)

# %%
c09.actions
# Out:
#             Dividends  Stock Splits
# Date
# 2000-06-08   0.056973           0.0
# 2001-06-05   0.056973           0.0
# 2002-06-04   0.056973           0.0
# 2003-06-03   0.056973           0.0
# 2004-05-04   0.500000           0.0
# 2005-05-03   0.075000           0.0
# 2006-05-02   0.050000           0.0
# 2006-12-05   0.075000           0.0
# 2007-04-30   0.100000           0.0
# 2007-10-09   0.100000           0.0
# 2008-05-06   0.125000           0.0
# 2009-05-05   0.075000           0.0
# 2010-05-04   0.080000           0.0
# 2011-05-03   0.100000           0.0
# 2011-09-01   0.050000           0.0
# 2012-04-30   0.050000           0.0
# 2013-04-29   0.050000           0.0
# 2013-08-13   0.080000           0.0
# 2014-04-30   0.080000           0.0
# 2014-08-21   0.040000           0.0
# 2015-04-30   0.040000           0.0
# 2015-08-20   0.040000           0.0
# 2016-05-03   0.040000           0.0
# 2016-08-19   0.040000           0.0
# 2017-04-27   0.040000           0.0
# ...

# %%
c09.major_holders
# Out:
#         0                                      1
# 0  43.59%        % of Shares Held by All Insider
# 1  13.42%       % of Shares Held by Institutions
# 2  23.79%        % of Float Held by Institutions
# 3     234  Number of Institutions Holding Shares

# %%
c09.institutional_holders
# Out:
#                                               Holder   Shares Date Reported  \
# 0  Vanguard International Stock Index-Total Intl ...  5969341    2021-07-31
# 1  Vanguard Tax Managed Fund-Vanguard Developed M...  3102574    2021-06-30
# 2               MFS International New Discovery Fund  2898600    2021-06-30
# 3                         iShares MSCI Singapore ETF  2805100    2021-09-30
# 4     Vanguard Global ex U.S. Real Estate Index Fund  2281890    2021-07-31
# 5                         DWS RREEF Real Assets Fund  2066300    2021-06-30
# 6                         iShares Core MSCI EAFE ETF  1967000    2021-09-30
# 7         Aberdeen Standard SICAV I-Asia Equity Fund  1897979    2021-02-28
# 8                    iShares ESG Aware MSCI EAFE ETF  1865200    2021-09-30
# 9                     DFA International Value Series  1599900    2021-07-31
#
#     % Out     Value
# 0  0.0066  40889985
# 1  0.0034  22617764
# 2  0.0032  21130794
# 3  0.0031  19383241
# 4  0.0025  15630946
# ...

# %%
yf.get_quote_table(c09)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-01688d695eda> in <module>
# ----> 1 yf.get_quote_table(c09)
#
# AttributeError: module 'yfinance' has no attribute 'get_quote_table'

# %% [markdown]
# ## Adv. Fin Data Gathering

# %%
tickers=['C09.SI','CLN.SI','F17.SI']

# %%
infos=[]
for i in tickers:
    infos.append(yf.Ticker(i).info)

# %%
infos
# Out:
# [{'zip': '048619',
#   'sector': 'Real Estate',
# ...

# %%
fundamentals=['dividendYield','marketCap','beta','forwardPE']

# %%
df=pd.DataFrame(infos)
df=df.set_index('symbol')
df
# Out:
#            zip       sector  \
# symbol
# C09.SI  048619  Real Estate
# CLN.SI  319394  Real Estate
# F17.SI  078881  Real Estate
#
#                                       longBusinessSummary       city  \
# symbol
# C09.SI  City Developments Limited (CDL) is a leading g...  Singapore
# CLN.SI  APAC Realty Limited provides real estate servi...  Singapore
# F17.SI  GuocoLand Limited, an investment holding compa...  Singapore
#
#                phone    country companyOfficers                       website  \
# symbol
# C09.SI  65 687 78228  Singapore              []         http://www.cdl.com.sg
# CLN.SI  65 6226 2000  Singapore              []  http://www.apacrealty.com.sg
# F17.SI  65 6535 6455  Singapore              []   http://www.guocoland.com.sg
#
#         maxAge                   address1  ...   bid tradeable dividendYield  \
# symbol                                     ...
# C09.SI       1            9 Raffles Place  ...  7.23     False        0.0111
# ...

# %%
df[df.columns[df.columns.isin(fundamentals)]]
# Out:
#             beta  forwardPE   marketCap  dividendYield
# symbol
# C09.SI  1.424858  11.312500  6565962752         0.0111
# CLN.SI  1.587217        NaN   291262368         0.0864
# F17.SI  0.682485   2.397059  1928893056         0.0366

# %%
plt.bar(df.index,df.dividendYield, color=('k','orange','cyan'))
plt.show()

# %%
df2 = pd.read_html('https://en.wikipedia.org/wiki/Straits_Times_Index')[3]
tickers=df2['Stock Symbol'].to_list()
tickers
# Out:
# ['SGX: A17U',
#  'SGX: C31',
#  'SGX: C38U',
#  'SGX: C09',
#  'SGX: C52',
#  'SGX: D01',
#  'SGX: D05',
#  'SGX: G13',
#  'SGX: H78',
#  'SGX: C07',
#  'SGX: J36',
#  'SGX: J37',
#  'SGX: BN4',
#  'SGX: AJBU',
#  'SGX: N2IU',
#  'SGX: ME8U',
#  'SGX: M44U',
#  'SGX: O39',
#  'SGX: S58',
#  'SGX: U96',
#  'SGX: C6L',
#  'SGX: Z74',
#  'SGX: S68',
#  'SGX: S63',
#  'SGX: Y92',
#  'SGX: U11',
#  'SGX: U14',
#  'SGX: V03',
#  'SGX: BS6',
#  'SGX: F34']

# %% [markdown]
# ## Using CSV

# %%
yf.Ticker('U14.SI').info
# Out:
# {'zip': '307591',
#  'sector': 'Real Estate',
#  'fullTimeEmployees': 2000,
# ...

# %%
quote=si.get_quote_table('U14.SI')
quote
# Out:
# {'1y Target Est': 8.6,
#  '52 Week Range': '6.67 - 8.03',
#  'Ask': '7.11 x 0',
#  'Avg. Volume': 1079287.0,
#  'Beta (5Y Monthly)': 0.96,
#  'Bid': '7.11 x 0',
#  "Day's Range": '7.09 - 7.19',
#  'EPS (TTM)': 0.22,
#  'Earnings Date': 'Feb 26, 2021',
#  'Ex-Dividend Date': 'Apr 30, 2021',
#  'Forward Dividend & Yield': '0.15 (2.11%)',
#  'Market Cap': '6.011B',
#  'Open': 7.18,
#  'PE Ratio (TTM)': 32.22,
#  'Previous Close': 7.17,
#  'Quote Price': 7.119999885559082,
#  'Volume': 729300.0}
